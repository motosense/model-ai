# %% [markdown]
# # Audio Classification: MotoSense

# %% [markdown]
# ## 1. Library & Konfigurasi

# %%
import os, glob, shutil, random, warnings
warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import json
import numpy as np
import pandas as pd
import librosa
import soundfile as sf

from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras import Sequential, layers, regularizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import joblib
import os
import pickle
import io
from IPython.display import display, Audio, clear_output
import ipywidgets as widgets
from audiomentations import (
    Compose,
    AddGaussianNoise,
    LowPassFilter,
    BandPassFilter,
    ClippingDistortion,
    Gain,
    PitchShift,
    TimeStretch,
    Shift,
    PolarityInversion,
    OneOf
)

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
import distutils.util
import matplotlib.gridspec as gridspec
import tensorflow_hub as hub
import numpy as np
import os
import glob
import librosa
import tensorflow as tf
from tensorflow.keras import layers, Sequential, regularizers
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix
)

BASE_DIR      = "dataset"
TARGET_SR     = 16000
DURATION      = 2
TARGET_SAMPLES = TARGET_SR * DURATION
STRIDE_SAMPLES = int(TARGET_SR * 1.5)

CLASSES       = ["Clutch-Shoe", "Conecting-Rod", "Drive-Belt",
                 "Piston", "Tensioner", "Slider", "Roller", "Face-Drive"]

N_MELS       = 128
N_FFT        = 1024
HOP_LENGTH   = 375

AUG_TARGET   = 2000

BATCH_SIZE   = 32
EPOCHS       = 500
LEARNING_RATE = 1e-3
SEED         = 42

PATHS = {
    "raw"         : os.path.join(BASE_DIR, "part-rusak"),
    "rename"      : os.path.join(BASE_DIR, "rename"),
    "preprocessed": os.path.join(BASE_DIR, "preprocessed"),
    "augmented"   : os.path.join(BASE_DIR, "augmented"),
    "split"       : os.path.join(BASE_DIR, "split"),

    "features"    : os.path.join(BASE_DIR, "features"),
    "models"      : "models",
}

for p in PATHS.values():
    os.makedirs(p, exist_ok=True)

# %%
# === ASSETS DIRECTORY SETUP ===
import os as _os
_ASSETS_DIR = r"/Users/macbook-airm2/Documents/CapstonePijak2026/assets"
_os.makedirs(_ASSETS_DIR, exist_ok=True)
print(f"Assets dir: {_ASSETS_DIR}")
# Out:
# Assets dir: /Users/macbook-airm2/Documents/CapstonePijak2026/assets

# %% [markdown]
# ## 2. Rename File

# %%
for cls in CLASSES:
    src = os.path.join(PATHS['raw'], cls)
    dst = os.path.join(PATHS['rename'], cls)
    os.makedirs(dst, exist_ok=True)
    files = sorted(f for f in os.listdir(src) if f.endswith(('.wav','.mp3','.m4a')))
    for i, f in enumerate(files, 1):
        ext = os.path.splitext(f)[1]
        shutil.copy(os.path.join(src, f),
                    os.path.join(dst, f"{cls.lower()}-{i:03d}{ext}"))
    print(f"  {cls:<15}: {len(files)} file")

print(f"\nDisimpan ke: {PATHS['rename']}")
# Out:
#   Clutch-Shoe    : 15 file
#   Conecting-Rod  : 10 file
#   Drive-Belt     : 20 file
#   Piston         : 6 file
#   Tensioner      : 8 file
#   Slider         : 13 file
#   Roller         : 19 file
#   Face-Drive     : 9 file
#
# Disimpan ke: dataset/rename

# %% [markdown]
# ## 3. EDA

# %%
durasi_dict = {}
total_files = 0

print(f"{'KELAS':<15} | {'FILE':<5} | {'SAMPLE RATE':<12} | {'RATA-RATA':<10} | {'MIN':<6} | {'MAX':<6}")
print("-" * 80)

for cls in sorted(os.listdir(PATHS["raw"])):

    path = os.path.join(PATHS["raw"], cls)

    if not os.path.isdir(path):
        continue

    files = [
        f for f in os.listdir(path)
        if f.lower().endswith((".wav", ".mp3", ".m4a"))
    ]

    if len(files) == 0:
        continue

    total_files += len(files)

    durasi_list = [
        librosa.get_duration(path=os.path.join(path, f))
        for f in files
    ]

    _, sr = librosa.load(
        os.path.join(path, files[0]),
        sr=None
    )

    durasi_dict[cls] = durasi_list

    print(
        f"{cls:<15} | "
        f"{len(files):<5} | "
        f"{sr:<12} | "
        f"{np.mean(durasi_list):<8.2f}s | "
        f"{np.min(durasi_list):<4.2f}s | "
        f"{np.max(durasi_list):<4.2f}s"
    )

print("-" * 80)
print(f"TOTAL FILE SELURUH KELAS: {total_files}")
# Out:
# KELAS           | FILE  | SAMPLE RATE  | RATA-RATA  | MIN    | MAX
# --------------------------------------------------------------------------------
# Clutch-Shoe     | 15    | 44100        | 2.51    s | 1.07s | 4.08s
# Conecting-Rod   | 10    | 44100        | 2.37    s | 1.62s | 4.21s
# Drive-Belt      | 20    | 44100        | 3.55    s | 1.60s | 6.75s
# Face-Drive      | 9     | 44100        | 3.14    s | 1.20s | 4.82s
# Piston          | 6     | 44100        | 1.74    s | 1.00s | 3.17s
# Roller          | 19    | 44100        | 3.78    s | 1.53s | 9.15s
# Slider          | 13    | 44100        | 3.91    s | 0.84s | 6.51s
# Tensioner       | 8     | 44100        | 2.97    s | 1.59s | 7.41s
# --------------------------------------------------------------------------------
# TOTAL FILE SELURUH KELAS: 100

# %%
for cls in sorted(os.listdir(PATHS["raw"])):

    path = os.path.join(PATHS["raw"], cls)

    if not os.path.isdir(path):
        continue

    files = sorted([
        f for f in os.listdir(path)
        if f.lower().endswith((".wav", ".mp3", ".m4a"))
    ])

    if len(files) == 0:
        continue

    sample_file = os.path.join(path, files[0])

    y, sr = librosa.load(
        sample_file,
        sr=None
    )

    mel_spec = librosa.feature.melspectrogram(
        y=y,
        sr=sr,
        n_mels=128
    )

    log_mel_spec = librosa.power_to_db(
        mel_spec,
        ref=np.max
    )

    plt.figure(figsize=(12, 6))

    plt.subplot(2, 1, 1)
    plt.plot(y)
    plt.title(f"{cls} - Waveform")
    plt.xlabel("Sample")
    plt.ylabel("Amplitude")

    plt.subplot(2, 1, 2)
    plt.imshow(
        log_mel_spec,
        aspect="auto",
        origin="lower"
    )

    plt.title(f"{cls} - Log-Mel Spectrogram")
    plt.xlabel("Frame")
    plt.ylabel("Mel Bin")
    plt.colorbar(format="%+2.0f dB")

    plt.tight_layout()
    os.makedirs(_ASSETS_DIR, exist_ok=True)
    plt.savefig(os.path.join(_ASSETS_DIR, f"waveform_melspec_{cls}.png"), dpi=150, bbox_inches="tight")
    plt.show()

# %% [markdown]
# ## 4. Preprocessing

# %%
def preprocess(path):
    y, _ = librosa.load(path, sr=TARGET_SR, mono=True)
    y, _ = librosa.effects.trim(y, top_db=30)
    peak  = np.max(np.abs(y))
    return y / peak if peak > 0 else y

def chunk_and_save(src_base, out_base):
    total = 0
    for cls in CLASSES:
        src_dir = os.path.join(src_base, cls)
        dst_dir = os.path.join(out_base, cls)
        os.makedirs(dst_dir, exist_ok=True)
        
        files = glob.glob(os.path.join(src_dir, '*.wav'))
        chunk_count = 0
        
        for f in files:
            audio = preprocess(f)
            base  = os.path.splitext(os.path.basename(f))[0]
            
            audio_len = len(audio)
            if audio_len < TARGET_SAMPLES:
                audio = np.tile(audio, int(np.ceil(TARGET_SAMPLES / audio_len)))
            
            chunks = [audio[i:i+TARGET_SAMPLES]
                     for i in range(0, len(audio)-TARGET_SAMPLES+1, STRIDE_SAMPLES)
                     if len(audio[i:i+TARGET_SAMPLES]) == TARGET_SAMPLES]
            
            for ci, chunk in enumerate(chunks):
                out_path = os.path.join(dst_dir, f"{base}_c{ci}.wav")
                sf.write(out_path, chunk, TARGET_SR, subtype='PCM_16')
                chunk_count += 1
        
        total += chunk_count
        print(f"  {cls:<15}: {chunk_count} chunks")
    
    return total

total_chunks = chunk_and_save(PATHS['rename'], PATHS['preprocessed'])
print(f"\n✓ Total chunks: {total_chunks} → {PATHS['preprocessed']}")
# Out:
#   Clutch-Shoe    : 19 chunks
#   Conecting-Rod  : 13 chunks
#   Drive-Belt     : 32 chunks
#   Piston         : 6 chunks
#   Tensioner      : 12 chunks
#   Slider         : 29 chunks
#   Roller         : 33 chunks
#   Face-Drive     : 15 chunks
#
# ✓ Total chunks: 159 → dataset/preprocessed

# %% [markdown]
# ## 5. Augmentasi

# %%
augment = Compose([

    OneOf([
        AddGaussianNoise(min_amplitude=0.001, max_amplitude=0.010, p=1.0),
    ], p=0.80),

    OneOf([
        LowPassFilter(min_cutoff_freq=2500, max_cutoff_freq=8000, p=1.0),
        BandPassFilter(min_center_freq=300, max_center_freq=6000, 
                      min_bandwidth_fraction=0.4, max_bandwidth_fraction=0.9, p=1.0),
        ClippingDistortion(max_percentile_threshold=5, p=1.0),
    ], p=0.45),

    Gain(min_gain_db=-10, max_gain_db=8, p=0.70),

    Shift(min_shift=-0.15, max_shift=0.15, rollover=True, p=0.55),

    TimeStretch(min_rate=0.95, max_rate=1.05, p=0.25),
    PitchShift(min_semitones=-1, max_semitones=1, p=0.15),

    PolarityInversion(p=0.10),
])

def augment_dataset(src_base, out_base, target_count=AUG_TARGET):
    """
    Augmentasi data:
    - Copy semua file asli
    - Tambahkan augmentasi hingga mencapai target_count
    """
    for cls in CLASSES:
        src_dir = os.path.join(src_base, cls)
        dst_dir = os.path.join(out_base, cls)
        os.makedirs(dst_dir, exist_ok=True)
        
        existing = glob.glob(os.path.join(src_dir, '*.wav'))
        if len(existing) == 0:
            print(f"  {cls:<15}: tidak ada file, dilewati")
            continue
        
        for f in existing:
            shutil.copy(f, os.path.join(dst_dir, os.path.basename(f)))
        
        needed = max(0, target_count - len(existing))
        
        for i in range(needed):
            src_file = random.choice(existing)
            y, _ = librosa.load(src_file, sr=TARGET_SR, mono=True)
            
            y_aug = augment(samples=y.astype(np.float32), sample_rate=TARGET_SR)
            
            if len(y_aug) < TARGET_SAMPLES:
                y_aug = np.pad(y_aug, (0, TARGET_SAMPLES - len(y_aug)))
            else:
                y_aug = y_aug[:TARGET_SAMPLES]
            
            out_path = os.path.join(dst_dir, f"aug_{i:05d}.wav")
            sf.write(out_path, y_aug, TARGET_SR, subtype='PCM_16')
        
        final = len(glob.glob(os.path.join(dst_dir, '*.wav')))
        print(f"  {cls:<15}: {len(existing):>3} asli → {final} total (+{needed} aug)")

augment_dataset(PATHS['preprocessed'], PATHS['augmented'])
print(f"\n✓ Disimpan ke: {PATHS['augmented']}")
# Out:
#   Clutch-Shoe    :  19 asli → 2000 total (+1981 aug)
#   Conecting-Rod  :  13 asli → 2000 total (+1987 aug)
#   Drive-Belt     :  32 asli → 2000 total (+1968 aug)
#   Piston         :   6 asli → 2000 total (+1994 aug)
#   Tensioner      :  12 asli → 2000 total (+1988 aug)
#   Slider         :  29 asli → 2000 total (+1971 aug)
#   Roller         :  33 asli → 2000 total (+1967 aug)
#   Face-Drive     :  15 asli → 2000 total (+1985 aug)
#
# ✓ Disimpan ke: dataset/augmented

# %% [markdown]
# ## 6. Train/Val/Test Split
#
# Split data awal untuk mencegah data leakage.

# %%
all_files, all_labels = [], []
for lbl, cls in enumerate(CLASSES):
    aug_dir = os.path.join(PATHS['augmented'], cls)
    for f in glob.glob(os.path.join(aug_dir, '*.wav')):
        all_files.append(f)
        all_labels.append(lbl)

print(f"Total file augmented: {len(all_files)}")

X_tmp, X_test, y_tmp, y_test = train_test_split(
    all_files, all_labels, 
    test_size=0.10,
    stratify=all_labels, 
    random_state=SEED
)

X_train, X_val, y_train, y_val = train_test_split(
    X_tmp, y_tmp, 
    test_size=0.111,
    stratify=y_tmp, 
    random_state=SEED
)

splits = [
    ("train", X_train, y_train),
    ("val",   X_val,   y_val),
    ("test",  X_test,  y_test)
]

for split_name, files, labels in splits:
    count = 0
    for f, lbl in zip(files, labels):
        cls = CLASSES[lbl]
        dst_dir = os.path.join(PATHS['split'], split_name, cls)
        os.makedirs(dst_dir, exist_ok=True)
        shutil.copy(f, os.path.join(dst_dir, os.path.basename(f)))
        count += 1
    
    pct = (count / len(all_files)) * 100
    print(f"  {split_name:<6}: {count:>4} file ({pct:>5.1f}%) → {os.path.join(PATHS['split'], split_name)}")

print(f"\n✓ Total: {len(all_files)} file")
print(f"✓ Train: {len(X_train)} | Val: {len(X_val)} | Test: {len(X_test)}")
# Out:
# Total file augmented: 16000
#   train : 12801 file ( 80.0%) → dataset/split/train
#   val   : 1599 file ( 10.0%) → dataset/split/val
#   test  : 1600 file ( 10.0%) → dataset/split/test
#
# ✓ Total: 16000 file
# ✓ Train: 12801 | Val: 1599 | Test: 1600

# %% [markdown]
# ## 7. Feature Extraction (Log-Mel Spectrogram)
#
# Konversi audio ke matriks 2D (128x128).

# %% [markdown]
# ### Visualisasi Spectrogram
#
# Sample perbandingan waveform dan spectrogram.

# %%
import random, matplotlib.pyplot as plt, librosa, librosa.display

sample_wavs = glob.glob(os.path.join(PATHS['split'],'train', '*', '*.wav'))
if sample_wavs:
    sample_path = random.choice(sample_wavs)
    cls_name    = os.path.basename(os.path.dirname(sample_path))
    y_s, sr_s   = librosa.load(sample_path, sr=TARGET_SR, mono=True)
    mel = librosa.feature.melspectrogram(y=y_s, sr=sr_s, n_fft=N_FFT, hop_length=HOP_LENGTH, n_mels=N_MELS)
    db  = librosa.power_to_db(mel, ref=np.max)
    fig, ax = plt.subplots(1, 2, figsize=(12, 4))
    librosa.display.waveshow(y_s, sr=sr_s, ax=ax[0], color='steelblue')
    ax[0].set_title(f'Waveform: {cls_name}')
    img = librosa.display.specshow(db, sr=sr_s, hop_length=HOP_LENGTH, x_axis='time', y_axis='mel', ax=ax[1], cmap='inferno')
    plt.colorbar(img, ax=ax[1], format='%+2.0f dB')
    ax[1].set_title(f'Log-Mel Spectrogram: {cls_name} | shape {db.shape}')
    os.makedirs(_ASSETS_DIR, exist_ok=True)
    plt.savefig(os.path.join(_ASSETS_DIR, "waveform_melspec_sample.png"), dpi=150, bbox_inches="tight")
    plt.tight_layout(); plt.show()

# %% [markdown]
# ### Feature Extraction with YAMNet

# %%
print("Memuat model YAMNet dari TF Hub...")
yamnet_model = hub.load('https://tfhub.dev/google/yamnet/1')
print("YAMNet berhasil dimuat!")

def extract_yamnet_embeddings(data_dir):
    X, y = [], []
    for lbl, cls in enumerate(CLASSES):
        files = glob.glob(os.path.join(data_dir, cls, '*.wav'))
        for f in files:
            wav, _ = librosa.load(f, sr=16000, mono=True)
            wav = wav / (np.max(np.abs(wav)) + 1e-8)
            _, embeddings, _ = yamnet_model(wav)

            emb = embeddings.numpy()

            emb_mean = np.mean(emb, axis=0)
            emb_std  = np.std(emb, axis=0)

            feature = np.concatenate([emb_mean, emb_std])
            X.append(emb_mean)
            y.append(lbl)
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.int32)
 
YAMNET_FEAT = {
    "train": (os.path.join(PATHS['features'], 'X_train_yamnet.npy'), os.path.join(PATHS['features'], 'y_train_yamnet.npy')),
    "val"  : (os.path.join(PATHS['features'], 'X_val_yamnet.npy'),   os.path.join(PATHS['features'], 'y_val_yamnet.npy')),
    "test" : (os.path.join(PATHS['features'], 'X_test_yamnet.npy'),  os.path.join(PATHS['features'], 'y_test_yamnet.npy')),
}
SRC = {
    "train": os.path.join(PATHS['split'], 'train'),
    "val": os.path.join(PATHS['split'], 'val'),
    "test": os.path.join(PATHS['split'], 'test')
}
print("\nEkstraksi fitur YAMNet...")
for subset, (xp, yp) in YAMNET_FEAT.items():
    if os.path.exists(xp):
        print(f"  {subset:<6}: cache ditemukan, skip")
    else:
        print(f"  {subset:<6}: mengekstrak...")
        X, y = extract_yamnet_embeddings(SRC[subset])
        np.save(xp, X); np.save(yp, y)
        print(f"  {subset:<6}: {X.shape} tersimpan")

X_train_yn = np.load(YAMNET_FEAT['train'][0]); y_train_yn = np.load(YAMNET_FEAT['train'][1])
X_val_yn   = np.load(YAMNET_FEAT['val'][0]);   y_val_yn   = np.load(YAMNET_FEAT['val'][1])
X_test_yn  = np.load(YAMNET_FEAT['test'][0]);  y_test_yn  = np.load(YAMNET_FEAT['test'][1])
print(f"\nX_train: {X_train_yn.shape} | X_val: {X_val_yn.shape} | X_test: {X_test_yn.shape}")

print("\nTrain :", X_train_yn.shape)
print("Val   :", X_val_yn.shape)
print("Test  :", X_test_yn.shape)

print("\nJumlah kelas:")
for i, cls in enumerate(CLASSES):
    print(cls, np.sum(y_train_yn == i))
# Out:
# Memuat model YAMNet dari TF Hub...
# YAMNet berhasil dimuat!
#
# Ekstraksi fitur YAMNet...
#   train : mengekstrak...
#   train : (12801, 1024) tersimpan
#   val   : mengekstrak...
#   val   : (1599, 1024) tersimpan
#   test  : mengekstrak...
#   test  : (1600, 1024) tersimpan
#
# X_train: (12801, 1024) | X_val: (1599, 1024) | X_test: (1600, 1024)
#
# Train : (12801, 1024)
# Val   : (1599, 1024)
# Test  : (1600, 1024)
#
# Jumlah kelas:
# Clutch-Shoe 1600
# Conecting-Rod 1601
# Drive-Belt 1600
# Piston 1600
# Tensioner 1600
# Slider 1600
# Roller 1600
# Face-Drive 1600

# %%
print("Train :", X_train_yn.shape)
print("Val   :", X_val_yn.shape)
print("Test  :", X_test_yn.shape)
# Out:
# Train : (12801, 1024)
# Val   : (1599, 1024)
# Test  : (1600, 1024)

# %%
all_wavs = glob.glob(os.path.join(PATHS['split'],'train', '*', '*.wav'))
example_path = random.choice(all_wavs)
cls_name = os.path.basename(os.path.dirname(example_path))

wav_orig, sr_orig = librosa.load(example_path, sr=None, mono=True)
wav_16k, _ = librosa.load(example_path, sr=16000, mono=True)
wav_16k_norm = wav_16k / (np.max(np.abs(wav_16k)) + 1e-8)

log_mel_out, embeddings, _ = yamnet_model(wav_16k_norm)
emb_mean = np.mean(embeddings.numpy(), axis=0)

fig = plt.figure(figsize=(18, 10))
fig.suptitle(f'Tahapan Ekstraksi Fitur YAMNet — Kelas: {cls_name}', fontsize=14)
gs = gridspec.GridSpec(2, 3, figure=fig, hspace=0.45, wspace=0.35)

ax1 = fig.add_subplot(gs[0, 0])
librosa.display.waveshow(wav_orig, sr=sr_orig, ax=ax1, color='steelblue')
ax1.set_title(f'1. Waveform Asli ({sr_orig} Hz)')

ax2 = fig.add_subplot(gs[0, 1])
librosa.display.waveshow(wav_16k_norm, sr=16000, ax=ax2, color='darkorange')
ax2.set_title('2. Resample 16kHz + Normalisasi')

ax3 = fig.add_subplot(gs[0, 2])
im3 = ax3.imshow(log_mel_out.numpy().T, origin='lower', aspect='auto', cmap='inferno')
plt.colorbar(im3, ax=ax3); ax3.set_title('3. Log-Mel Spectrogram Internal YAMNet')

ax4 = fig.add_subplot(gs[1, 0:2])
im4 = ax4.imshow(embeddings.numpy().T, origin='lower', aspect='auto', cmap='viridis')
plt.colorbar(im4, ax=ax4); ax4.set_title(f'4. Embedding Matrix {embeddings.numpy().shape}')

ax5 = fig.add_subplot(gs[1, 2])
ax5.plot(emb_mean, color='mediumseagreen', linewidth=0.8)
ax5.fill_between(range(len(emb_mean)), emb_mean, alpha=0.3, color='mediumseagreen')
ax5.set_title(f'5. Embedding Final {emb_mean.shape}'); ax5.grid(alpha=0.3)
os.makedirs(_ASSETS_DIR, exist_ok=True)
plt.savefig(os.path.join(_ASSETS_DIR, "yamnet_feature_extraction.png"), dpi=150, bbox_inches="tight")
plt.show()

# %%
emb = embeddings.numpy()

print("Min :", emb.min())
print("Max :", emb.max())
print("Mean:", emb.mean())
print("Std :", emb.std())
# Out:
# Min : 0.0
# Max : 2.8620799
# Mean: 0.052253895
# Std : 0.21859093

# %%
plt.figure(figsize=(8,4))
plt.hist(embeddings.numpy().flatten(), bins=100)
plt.title("Distribusi Nilai Embedding YAMNet")
plt.xlabel("Nilai")
plt.ylabel("Jumlah")
os.makedirs(_ASSETS_DIR, exist_ok=True)
plt.savefig(os.path.join(_ASSETS_DIR, "yamnet_embedding_distribution.png"), dpi=150, bbox_inches="tight")
plt.show()

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=2)

X_pca = pca.fit_transform(X_train_yn)

plt.figure(figsize=(8,6))

for i, cls in enumerate(CLASSES):
    idx = y_train_yn == i
    plt.scatter(
        X_pca[idx,0],
        X_pca[idx,1],
        label=cls,
        alpha=0.7
    )

plt.legend()
plt.title("PCA Embedding YAMNet")
os.makedirs(_ASSETS_DIR, exist_ok=True)
plt.savefig(os.path.join(_ASSETS_DIR, "pca_embedding.png"), dpi=150, bbox_inches="tight")
plt.show()

# %%
import umap
import matplotlib.pyplot as plt

reducer = umap.UMAP(n_components=2, n_neighbors=15, min_dist=0.1, random_state=42)

X_umap = reducer.fit_transform(X_train_yn)

plt.figure(figsize=(8,6))

for i, cls in enumerate(CLASSES):
    idx = y_train_yn == i
    plt.scatter(
        X_umap[idx, 0],
        X_umap[idx, 1],
        label=cls,
        alpha=0.7
    )

plt.legend()
plt.title("UMAP Embedding YAMNet")
os.makedirs(_ASSETS_DIR, exist_ok=True)
plt.savefig(os.path.join(_ASSETS_DIR, "umap_embedding.png"), dpi=150, bbox_inches="tight")
plt.show()
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

tsne = TSNE(n_components=2, perplexity=30, random_state=42)

X_tsne = tsne.fit_transform(X_train_yn)

plt.figure(figsize=(8,6))

for i, cls in enumerate(CLASSES):
    idx = y_train_yn == i
    plt.scatter(
        X_tsne[idx, 0],
        X_tsne[idx, 1],
        label=cls,
        alpha=0.7
    )

plt.legend()
plt.title("t-SNE Embedding YAMNet")
os.makedirs(_ASSETS_DIR, exist_ok=True)
plt.savefig(os.path.join(_ASSETS_DIR, "tsne_embedding.png"), dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 8. Training

# %% [markdown]
# ### Standarisasi

# %%
scaler = StandardScaler()

X_train_sq = scaler.fit_transform(X_train_yn)

X_val_sq = scaler.transform(X_val_yn)

X_test_sq = scaler.transform(X_test_yn)

y_train_sq = y_train_yn
y_val_sq = y_val_yn
y_test_sq = y_test_yn

# %% [markdown]
# ## 8.1 Dense Sequential model Arsitektur

# %%
def build_yamnet_classifier(n_classes, l2_strength=1e-4, dropout_rate=0.5):
    return Sequential([
        # Input layer
        layers.Input(shape=(1024,), name='input_embeddings'),
        
        # First hidden layer: 1024 → 512
        layers.Dense(512, kernel_regularizer=regularizers.l2(l2_strength)),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.5),
        
        # Second hidden layer: 512 → 256
        layers.Dense(256, kernel_regularizer=regularizers.l2(l2_strength)),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(dropout_rate),
        
        # Third hidden layer: 256 → 128
        layers.Dense(128, kernel_regularizer=regularizers.l2(l2_strength)),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.5),
        
        # Output layer: 128 → n_classes
        layers.Dense(n_classes, activation='softmax', name='output')
    ], name="yamnet_dense")

model = build_yamnet_classifier(len(CLASSES))
model.summary()
# Out:
# Model: "yamnet_dense"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 693,640 (2.65 MB)
#  Trainable params: 691,848 (2.64 MB)
#  Non-trainable params: 1,792 (7.00 KB)

# %% [markdown]
# ### Traning & Callback

# %%
model_yn = build_yamnet_classifier(len(CLASSES))
model_yn.compile(optimizer=tf.keras.optimizers.Adam(LEARNING_RATE),
                 loss='sparse_categorical_crossentropy', metrics=['accuracy'])

callbacks_yn = [
    EarlyStopping(monitor='val_loss', patience=20,min_delta=0.001, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=7, min_lr=1e-7, verbose=1)
]

print("Training YAMNet Dense Classifier...")
history_yn = model_yn.fit(
    X_train_yn, y_train_yn,
    validation_data=(X_val_yn, y_val_yn),
    epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=callbacks_yn, verbose=1
)

loss, acc = model_yn.evaluate(X_test_yn, y_test_yn, verbose=0)
print(f"\nAkurasi YAMNet Dense pada Test Set: {acc*100:.2f}%")

fig, ax = plt.subplots(1, 2, figsize=(12, 4))
ep = range(1, len(history_yn.history['loss']) + 1)
ax[0].plot(ep, history_yn.history['accuracy'],     label='train')
ax[0].plot(ep, history_yn.history['val_accuracy'], label='val')
ax[0].set_title('YAMNet Dense Accuracy'); ax[0].legend(); ax[0].grid(alpha=0.3)
ax[1].plot(ep, history_yn.history['loss'],     label='train')
ax[1].plot(ep, history_yn.history['val_loss'], label='val')
ax[1].set_title('YAMNet Dense Loss'); ax[1].legend(); ax[1].grid(alpha=0.3)
os.makedirs(_ASSETS_DIR, exist_ok=True)
plt.savefig(os.path.join(_ASSETS_DIR, "yamnet_dense_training.png"), dpi=150, bbox_inches="tight")
plt.tight_layout(); plt.show()
# Out:
# Training YAMNet Dense Classifier...
# Epoch 1/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6816 - loss: 1.0388 - val_accuracy: 0.8730 - val_loss: 0.4424 - learning_rate: 0.0010
# Epoch 2/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8273 - loss: 0.5915 - val_accuracy: 0.9012 - val_loss: 0.3614 - learning_rate: 0.0010
# Epoch 3/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8477 - loss: 0.5206 - val_accuracy: 0.8974 - val_loss: 0.3587 - learning_rate: 0.0010
# Epoch 4/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8665 - loss: 0.4637 - val_accuracy: 0.9268 - val_loss: 0.3155 - learning_rate: 0.0010
# Epoch 5/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8767 - loss: 0.4477 - val_accuracy: 0.9293 - val_loss: 0.3055 - learning_rate: 0.0010
# Epoch 6/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8850 - loss: 0.4255 - val_accuracy: 0.9368 - val_loss: 0.2980 - learning_rate: 0.0010
# Epoch 7/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8882 - loss: 0.4137 - val_accuracy: 0.9312 - val_loss: 0.2916 - learning_rate: 0.0010
# Epoch 8/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8926 - loss: 0.4138 - val_accuracy: 0.9381 - val_loss: 0.2921 - learning_rate: 0.0010
# Epoch 9/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8973 - loss: 0.4084 - val_accuracy: 0.9293 - val_loss: 0.3059 - learning_rate: 0.0010
# Epoch 10/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8997 - loss: 0.3987 - val_accuracy: 0.9375 - val_loss: 0.2943 - learning_rate: 0.0010
# Epoch 11/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9055 - loss: 0.3874 - val_accuracy: 0.9393 - val_loss: 0.2875 - learning_rate: 0.0010
# Epoch 12/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9034 - loss: 0.3896 - val_accuracy: 0.9362 - val_loss: 0.2881 - learning_rate: 0.0010
# Epoch 13/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9074 - loss: 0.3866 - val_accuracy: 0.9400 - val_loss: 0.2869 - learning_rate: 0.0010
# Epoch 14/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9106 - loss: 0.3783 - val_accuracy: 0.9387 - val_loss: 0.2896 - learning_rate: 0.0010
# Epoch 15/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9099 - loss: 0.3806 - val_accuracy: 0.9418 - val_loss: 0.2901 - learning_rate: 0.0010
# Epoch 16/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9140 - loss: 0.3784 - val_accuracy: 0.9450 - val_loss: 0.2874 - learning_rate: 0.0010
# Epoch 17/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9127 - loss: 0.3785 - val_accuracy: 0.9456 - val_loss: 0.2934 - learning_rate: 0.0010
# Epoch 18/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9181 - loss: 0.3662 - val_accuracy: 0.9425 - val_loss: 0.2881 - learning_rate: 0.0010
# Epoch 19/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9198 - loss: 0.3707 - val_accuracy: 0.9431 - val_loss: 0.2853 - learning_rate: 0.0010
# Epoch 20/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9170 - loss: 0.3711 - val_accuracy: 0.9425 - val_loss: 0.3001 - learning_rate: 0.0010
# Epoch 21/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9146 - loss: 0.3725 - val_accuracy: 0.9462 - val_loss: 0.2951 - learning_rate: 0.0010
# Epoch 22/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9214 - loss: 0.3633 - val_accuracy: 0.9450 - val_loss: 0.2869 - learning_rate: 0.0010
# Epoch 23/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9186 - loss: 0.3690 - val_accuracy: 0.9406 - val_loss: 0.2952 - learning_rate: 0.0010
# Epoch 24/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9187 - loss: 0.3645 - val_accuracy: 0.9456 - val_loss: 0.2903 - learning_rate: 0.0010
# Epoch 25/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9234 - loss: 0.3608 - val_accuracy: 0.9481 - val_loss: 0.2859 - learning_rate: 0.0010
# Epoch 26/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9242 - loss: 0.3584 - val_accuracy: 0.9475 - val_loss: 0.2849 - learning_rate: 0.0010
# Epoch 27/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9260 - loss: 0.3570 - val_accuracy: 0.9456 - val_loss: 0.2849 - learning_rate: 0.0010
# Epoch 28/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9245 - loss: 0.3611 - val_accuracy: 0.9481 - val_loss: 0.2892 - learning_rate: 0.0010
# Epoch 29/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9255 - loss: 0.3549 - val_accuracy: 0.9531 - val_loss: 0.2779 - learning_rate: 0.0010
# Epoch 30/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9266 - loss: 0.3538 - val_accuracy: 0.9475 - val_loss: 0.2858 - learning_rate: 0.0010
# Epoch 31/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9264 - loss: 0.3487 - val_accuracy: 0.9506 - val_loss: 0.2789 - learning_rate: 0.0010
# Epoch 32/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9251 - loss: 0.3615 - val_accuracy: 0.9531 - val_loss: 0.2828 - learning_rate: 0.0010
# Epoch 33/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9252 - loss: 0.3596 - val_accuracy: 0.9512 - val_loss: 0.2860 - learning_rate: 0.0010
# Epoch 34/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9295 - loss: 0.3526 - val_accuracy: 0.9481 - val_loss: 0.2871 - learning_rate: 0.0010
# Epoch 35/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9285 - loss: 0.3423 - val_accuracy: 0.9531 - val_loss: 0.2734 - learning_rate: 0.0010
# Epoch 36/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9298 - loss: 0.3438 - val_accuracy: 0.9493 - val_loss: 0.2867 - learning_rate: 0.0010
# Epoch 37/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9284 - loss: 0.3475 - val_accuracy: 0.9518 - val_loss: 0.2827 - learning_rate: 0.0010
# Epoch 38/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9302 - loss: 0.3510 - val_accuracy: 0.9543 - val_loss: 0.2805 - learning_rate: 0.0010
# Epoch 39/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9302 - loss: 0.3455 - val_accuracy: 0.9493 - val_loss: 0.2869 - learning_rate: 0.0010
# Epoch 40/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9299 - loss: 0.3518 - val_accuracy: 0.9493 - val_loss: 0.2851 - learning_rate: 0.0010
# Epoch 41/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9296 - loss: 0.3531 - val_accuracy: 0.9556 - val_loss: 0.2860 - learning_rate: 0.0010
# Epoch 42/500
# 389/401 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9374 - loss: 0.3383
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9344 - loss: 0.3444 - val_accuracy: 0.9525 - val_loss: 0.2875 - learning_rate: 0.0010
# Epoch 43/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9398 - loss: 0.3194 - val_accuracy: 0.9606 - val_loss: 0.2647 - learning_rate: 5.0000e-04
# Epoch 44/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9467 - loss: 0.2941 - val_accuracy: 0.9593 - val_loss: 0.2629 - learning_rate: 5.0000e-04
# Epoch 45/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9479 - loss: 0.2896 - val_accuracy: 0.9562 - val_loss: 0.2597 - learning_rate: 5.0000e-04
# Epoch 46/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9512 - loss: 0.2850 - val_accuracy: 0.9568 - val_loss: 0.2522 - learning_rate: 5.0000e-04
# Epoch 47/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9498 - loss: 0.2807 - val_accuracy: 0.9581 - val_loss: 0.2530 - learning_rate: 5.0000e-04
# Epoch 48/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9499 - loss: 0.2763 - val_accuracy: 0.9593 - val_loss: 0.2476 - learning_rate: 5.0000e-04
# Epoch 49/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9524 - loss: 0.2703 - val_accuracy: 0.9568 - val_loss: 0.2538 - learning_rate: 5.0000e-04
# Epoch 50/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9527 - loss: 0.2678 - val_accuracy: 0.9593 - val_loss: 0.2458 - learning_rate: 5.0000e-04
# Epoch 51/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9527 - loss: 0.2712 - val_accuracy: 0.9562 - val_loss: 0.2466 - learning_rate: 5.0000e-04
# Epoch 52/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9524 - loss: 0.2626 - val_accuracy: 0.9606 - val_loss: 0.2386 - learning_rate: 5.0000e-04
# Epoch 53/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9541 - loss: 0.2582 - val_accuracy: 0.9606 - val_loss: 0.2446 - learning_rate: 5.0000e-04
# Epoch 54/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9554 - loss: 0.2553 - val_accuracy: 0.9631 - val_loss: 0.2428 - learning_rate: 5.0000e-04
# Epoch 55/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9548 - loss: 0.2562 - val_accuracy: 0.9581 - val_loss: 0.2439 - learning_rate: 5.0000e-04
# Epoch 56/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9569 - loss: 0.2467 - val_accuracy: 0.9537 - val_loss: 0.2414 - learning_rate: 5.0000e-04
# Epoch 57/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9551 - loss: 0.2496 - val_accuracy: 0.9600 - val_loss: 0.2317 - learning_rate: 5.0000e-04
# Epoch 58/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9538 - loss: 0.2507 - val_accuracy: 0.9568 - val_loss: 0.2399 - learning_rate: 5.0000e-04
# Epoch 59/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9538 - loss: 0.2506 - val_accuracy: 0.9587 - val_loss: 0.2307 - learning_rate: 5.0000e-04
# Epoch 60/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 92s 231ms/step - accuracy: 0.9624 - loss: 0.2318 - val_accuracy: 0.9600 - val_loss: 0.2355 - learning_rate: 5.0000e-04
# Epoch 61/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 39s 96ms/step - accuracy: 0.9613 - loss: 0.2303 - val_accuracy: 0.9637 - val_loss: 0.2348 - learning_rate: 5.0000e-04
# Epoch 62/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.9581 - loss: 0.2384 - val_accuracy: 0.9600 - val_loss: 0.2351 - learning_rate: 5.0000e-04
# Epoch 63/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.9571 - loss: 0.2385 - val_accuracy: 0.9631 - val_loss: 0.2325 - learning_rate: 5.0000e-04
# Epoch 64/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9568 - loss: 0.2386 - val_accuracy: 0.9606 - val_loss: 0.2281 - learning_rate: 5.0000e-04
# Epoch 65/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9624 - loss: 0.2253 - val_accuracy: 0.9612 - val_loss: 0.2333 - learning_rate: 5.0000e-04
# Epoch 66/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9600 - loss: 0.2295 - val_accuracy: 0.9575 - val_loss: 0.2441 - learning_rate: 5.0000e-04
# Epoch 67/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9604 - loss: 0.2291 - val_accuracy: 0.9581 - val_loss: 0.2432 - learning_rate: 5.0000e-04
# Epoch 68/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9613 - loss: 0.2268 - val_accuracy: 0.9562 - val_loss: 0.2376 - learning_rate: 5.0000e-04
# Epoch 69/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9598 - loss: 0.2344 - val_accuracy: 0.9631 - val_loss: 0.2281 - learning_rate: 5.0000e-04
# Epoch 70/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9605 - loss: 0.2271 - val_accuracy: 0.9619 - val_loss: 0.2278 - learning_rate: 5.0000e-04
# Epoch 71/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9584 - loss: 0.2350 - val_accuracy: 0.9662 - val_loss: 0.2216 - learning_rate: 5.0000e-04
# Epoch 72/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.9607 - loss: 0.2230 - val_accuracy: 0.9587 - val_loss: 0.2309 - learning_rate: 5.0000e-04
# Epoch 73/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.9619 - loss: 0.2206 - val_accuracy: 0.9644 - val_loss: 0.2229 - learning_rate: 5.0000e-04
# Epoch 74/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9593 - loss: 0.2267 - val_accuracy: 0.9606 - val_loss: 0.2345 - learning_rate: 5.0000e-04
# Epoch 75/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9621 - loss: 0.2195 - val_accuracy: 0.9543 - val_loss: 0.2393 - learning_rate: 5.0000e-04
# Epoch 76/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9609 - loss: 0.2245 - val_accuracy: 0.9593 - val_loss: 0.2288 - learning_rate: 5.0000e-04
# Epoch 77/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9619 - loss: 0.2237 - val_accuracy: 0.9581 - val_loss: 0.2295 - learning_rate: 5.0000e-04
# Epoch 78/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9632 - loss: 0.2251
# Epoch 78: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9617 - loss: 0.2263 - val_accuracy: 0.9612 - val_loss: 0.2234 - learning_rate: 5.0000e-04
# Epoch 79/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9656 - loss: 0.2079 - val_accuracy: 0.9606 - val_loss: 0.2278 - learning_rate: 2.5000e-04
# Epoch 80/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9695 - loss: 0.1956 - val_accuracy: 0.9637 - val_loss: 0.2260 - learning_rate: 2.5000e-04
# Epoch 81/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9695 - loss: 0.1968 - val_accuracy: 0.9644 - val_loss: 0.2267 - learning_rate: 2.5000e-04
# Epoch 82/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9725 - loss: 0.1897 - val_accuracy: 0.9637 - val_loss: 0.2265 - learning_rate: 2.5000e-04
# Epoch 83/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9740 - loss: 0.1842 - val_accuracy: 0.9637 - val_loss: 0.2264 - learning_rate: 2.5000e-04
# Epoch 84/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9730 - loss: 0.1842 - val_accuracy: 0.9656 - val_loss: 0.2208 - learning_rate: 2.5000e-04
# Epoch 85/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9716 - loss: 0.1801 - val_accuracy: 0.9625 - val_loss: 0.2249 - learning_rate: 2.5000e-04
# Epoch 86/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9743 - loss: 0.1730 - val_accuracy: 0.9631 - val_loss: 0.2239 - learning_rate: 2.5000e-04
# Epoch 87/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9746 - loss: 0.1747 - val_accuracy: 0.9625 - val_loss: 0.2253 - learning_rate: 2.5000e-04
# Epoch 88/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9755 - loss: 0.1698 - val_accuracy: 0.9619 - val_loss: 0.2199 - learning_rate: 2.5000e-04
# Epoch 89/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9741 - loss: 0.1752 - val_accuracy: 0.9637 - val_loss: 0.2174 - learning_rate: 2.5000e-04
# Epoch 90/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9755 - loss: 0.1704 - val_accuracy: 0.9675 - val_loss: 0.2216 - learning_rate: 2.5000e-04
# Epoch 91/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9753 - loss: 0.1691 - val_accuracy: 0.9662 - val_loss: 0.2196 - learning_rate: 2.5000e-04
# Epoch 92/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9758 - loss: 0.1698 - val_accuracy: 0.9650 - val_loss: 0.2150 - learning_rate: 2.5000e-04
# Epoch 93/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9755 - loss: 0.1679 - val_accuracy: 0.9606 - val_loss: 0.2286 - learning_rate: 2.5000e-04
# Epoch 94/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9719 - loss: 0.1752 - val_accuracy: 0.9625 - val_loss: 0.2176 - learning_rate: 2.5000e-04
# Epoch 95/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9777 - loss: 0.1608 - val_accuracy: 0.9662 - val_loss: 0.2119 - learning_rate: 2.5000e-04
# Epoch 96/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9770 - loss: 0.1599 - val_accuracy: 0.9656 - val_loss: 0.2141 - learning_rate: 2.5000e-04
# Epoch 97/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9778 - loss: 0.1584 - val_accuracy: 0.9650 - val_loss: 0.2263 - learning_rate: 2.5000e-04
# Epoch 98/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9764 - loss: 0.1575 - val_accuracy: 0.9656 - val_loss: 0.2167 - learning_rate: 2.5000e-04
# Epoch 99/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9747 - loss: 0.1640 - val_accuracy: 0.9637 - val_loss: 0.2080 - learning_rate: 2.5000e-04
# Epoch 100/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9769 - loss: 0.1575 - val_accuracy: 0.9687 - val_loss: 0.2184 - learning_rate: 2.5000e-04
# Epoch 101/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9763 - loss: 0.1599 - val_accuracy: 0.9644 - val_loss: 0.2166 - learning_rate: 2.5000e-04
# Epoch 102/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9784 - loss: 0.1560 - val_accuracy: 0.9631 - val_loss: 0.2156 - learning_rate: 2.5000e-04
# Epoch 103/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9760 - loss: 0.1582 - val_accuracy: 0.9593 - val_loss: 0.2200 - learning_rate: 2.5000e-04
# Epoch 104/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9805 - loss: 0.1508 - val_accuracy: 0.9644 - val_loss: 0.2156 - learning_rate: 2.5000e-04
# Epoch 105/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9798 - loss: 0.1492 - val_accuracy: 0.9681 - val_loss: 0.2061 - learning_rate: 2.5000e-04
# Epoch 106/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9789 - loss: 0.1523 - val_accuracy: 0.9669 - val_loss: 0.2123 - learning_rate: 2.5000e-04
# Epoch 107/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9795 - loss: 0.1482 - val_accuracy: 0.9625 - val_loss: 0.2217 - learning_rate: 2.5000e-04
# Epoch 108/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9777 - loss: 0.1507 - val_accuracy: 0.9656 - val_loss: 0.2144 - learning_rate: 2.5000e-04
# Epoch 109/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9768 - loss: 0.1579 - val_accuracy: 0.9675 - val_loss: 0.2140 - learning_rate: 2.5000e-04
# Epoch 110/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9753 - loss: 0.1534 - val_accuracy: 0.9625 - val_loss: 0.2109 - learning_rate: 2.5000e-04
# Epoch 111/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9783 - loss: 0.1483 - val_accuracy: 0.9650 - val_loss: 0.2127 - learning_rate: 2.5000e-04
# Epoch 112/500
# 395/401 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9794 - loss: 0.1471
# Epoch 112: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9787 - loss: 0.1484 - val_accuracy: 0.9612 - val_loss: 0.2106 - learning_rate: 2.5000e-04
# Epoch 113/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9824 - loss: 0.1369 - val_accuracy: 0.9625 - val_loss: 0.2079 - learning_rate: 1.2500e-04
# Epoch 114/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9814 - loss: 0.1415 - val_accuracy: 0.9644 - val_loss: 0.2117 - learning_rate: 1.2500e-04
# Epoch 115/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9832 - loss: 0.1357 - val_accuracy: 0.9650 - val_loss: 0.2088 - learning_rate: 1.2500e-04
# Epoch 116/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9845 - loss: 0.1300 - val_accuracy: 0.9656 - val_loss: 0.2123 - learning_rate: 1.2500e-04
# Epoch 117/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9834 - loss: 0.1319 - val_accuracy: 0.9644 - val_loss: 0.2147 - learning_rate: 1.2500e-04
# Epoch 118/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9844 - loss: 0.1297 - val_accuracy: 0.9669 - val_loss: 0.2152 - learning_rate: 1.2500e-04
# Epoch 119/500
# 396/401 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9824 - loss: 0.1334
# Epoch 119: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9832 - loss: 0.1323 - val_accuracy: 0.9625 - val_loss: 0.2159 - learning_rate: 1.2500e-04
# Epoch 120/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9857 - loss: 0.1228 - val_accuracy: 0.9644 - val_loss: 0.2086 - learning_rate: 6.2500e-05
# Epoch 121/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9859 - loss: 0.1248 - val_accuracy: 0.9650 - val_loss: 0.2093 - learning_rate: 6.2500e-05
# Epoch 122/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9872 - loss: 0.1199 - val_accuracy: 0.9675 - val_loss: 0.2109 - learning_rate: 6.2500e-05
# Epoch 123/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9874 - loss: 0.1203 - val_accuracy: 0.9675 - val_loss: 0.2098 - learning_rate: 6.2500e-05
# Epoch 124/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9866 - loss: 0.1186 - val_accuracy: 0.9656 - val_loss: 0.2125 - learning_rate: 6.2500e-05
# Epoch 125/500
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9888 - loss: 0.1177 - val_accuracy: 0.9662 - val_loss: 0.2181 - learning_rate: 6.2500e-05
# Epoch 125: early stopping
# Restoring model weights from the end of the best epoch: 105.
#
# Akurasi YAMNet Dense pada Test Set: 95.75%

# %% [markdown]
# ### Clasification Report

# %%
from sklearn.metrics import classification_report

y_pred = np.argmax(
    model_yn.predict(X_test_yn),
    axis=1
)

print(
    classification_report(
        y_test_yn,
        y_pred,
        target_names=CLASSES
    )
)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 786us/step
#                precision    recall  f1-score   support
#
#   Clutch-Shoe       0.94      0.97      0.95       200
# Conecting-Rod       0.98      0.99      0.99       200
#    Drive-Belt       0.99      0.96      0.98       200
#        Piston       0.96      0.97      0.97       200
#     Tensioner       0.96      0.96      0.96       200
#        Slider       0.96      0.93      0.94       200
#        Roller       0.94      0.94      0.94       200
#    Face-Drive       0.93      0.93      0.93       200
#
#      accuracy                           0.96      1600
#     macro avg       0.96      0.96      0.96      1600
#  weighted avg       0.96      0.96      0.96      1600

# %% [markdown]
# ### confusion matriks

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test_sq, y_pred)

plt.figure(figsize=(8,6))

sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap= 'Blues',
    xticklabels=CLASSES,
    yticklabels=CLASSES
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - YAMNet + Squential")

plt.tight_layout()
os.makedirs(_ASSETS_DIR, exist_ok=True)
plt.savefig(os.path.join(_ASSETS_DIR, "confusion_matrix_sequential.png"), dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Save Model

# %%
import os

SEQ_DIRS = {
    'keras': os.path.join(PATHS['models'], 'sequential', 'keras'),
    'tflite': os.path.join(PATHS['models'], 'sequential', 'tflite'),

    'scaler': os.path.join(PATHS['models'], 'sequential', 'scaler'),
    'metadata': os.path.join(PATHS['models'], 'sequential', 'metadata'),
}

for path in SEQ_DIRS.values():
    os.makedirs(path, exist_ok=True)

for key, path in SEQ_DIRS.items():
    print(f"{key:<10}: {path}")
# Out:
# keras     : models/sequential/keras
# tflite    : models/sequential/tflite
# scaler    : models/sequential/scaler
# metadata  : models/sequential/metadata

# %%
h5_path = os.path.join(
    SEQ_DIRS['keras'],
    'yamnet_sequential.h5'
)

model_yn.save(h5_path)

print(f"Saved H5 : {h5_path}")

keras_path = os.path.join(
    SEQ_DIRS['keras'],
    'yamnet_sequential.keras'
)

model_yn.save(keras_path)

print(f"Saved Keras : {keras_path}")

tflite_path = os.path.join(
    SEQ_DIRS['tflite'],
    'yamnet_sequential.tflite'
)

converter = tf.lite.TFLiteConverter.from_keras_model(
    model_yn
)

tflite_model = converter.convert()

with open(tflite_path, "wb") as f:
    f.write(tflite_model)

print(f"Saved TFLite : {tflite_path}")

import joblib

joblib.dump(
    scaler,
    os.path.join(
        SEQ_DIRS['scaler'],
        'yamnet_scaler.joblib'
    )
)

print("Scaler saved")

metadata = {
    "classes": CLASSES,
    "num_classes": len(CLASSES),
    "feature_extractor": "YAMNet",
    "embedding_size": int(X_train_yn.shape[1])

}

with open(
    os.path.join(
        SEQ_DIRS['metadata'],
        'metadata.json'
    ),
    'w'
) as f:
    json.dump(metadata, f, indent=4)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved H5 : models/sequential/keras/yamnet_sequential.h5
# Saved Keras : models/sequential/keras/yamnet_sequential.keras
# INFO:tensorflow:Assets written to: /var/folders/56/db9c3yn534757rq3twrpchw40000gn/T/tmpfk4p0e6p/assets
# INFO:tensorflow:Assets written to: /var/folders/56/db9c3yn534757rq3twrpchw40000gn/T/tmpfk4p0e6p/assets
# Saved artifact at '/var/folders/56/db9c3yn534757rq3twrpchw40000gn/T/tmpfk4p0e6p'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 1024), dtype=tf.float32, name='input_embeddings')
# Output Type:
#   TensorSpec(shape=(None, 8), dtype=tf.float32, name=None)
# Captures:
#   14371643344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14371648144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14371646992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14371647376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14371641616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14371650832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14371647184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14371650064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14371649488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14371646224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14371637968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14371649296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14371650256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14371649680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14371649104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14371648912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14371643728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14371636048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14371641232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14371639888: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved TFLite : models/sequential/tflite/yamnet_sequential.tflite
# Scaler saved

# %% [markdown]
# ## 8.2 SVM

# %%
from sklearn.preprocessing import StandardScaler

print("\nNormalisasi fitur YAMNet untuk SVM...")

scaler_svm = StandardScaler()

X_train_svm = scaler_svm.fit_transform(X_train_yn)
X_val_svm   = scaler_svm.transform(X_val_yn)
X_test_svm  = scaler_svm.transform(X_test_yn)

y_train_svm = y_train_yn
y_val_svm   = y_val_yn
y_test_svm  = y_test_yn

print("Normalisasi SVM selesai.")
# Out:
# Normalisasi fitur YAMNet untuk SVM...
# Normalisasi SVM selesai.

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

svm_model = SVC(
    kernel='rbf',
    C=10,
    gamma='scale',
    probability=True,
    random_state=42
)

print("Training SVM...")

svm_model.fit(X_train_svm, y_train_svm)

val_pred = svm_model.predict(X_val_svm)
val_acc = accuracy_score(y_val_svm, val_pred)

print(f"Validation Accuracy : {val_acc*100:.2f}%")
# Out:
# Training SVM...
# Validation Accuracy : 93.87%

# %%
test_pred = svm_model.predict(X_test_svm)

test_acc = accuracy_score(y_test_svm, test_pred)

print(f"\nTest Accuracy : {test_acc*100:.2f}%")
# Out:
# Test Accuracy : 92.31%

# %%
from sklearn.metrics import classification_report

print(
    classification_report(
        y_test_svm,
        test_pred,
        target_names=CLASSES
    )
)
# Out:
#                precision    recall  f1-score   support
#
#   Clutch-Shoe       0.77      0.96      0.86       200
# Conecting-Rod       0.97      0.94      0.95       200
#    Drive-Belt       0.94      0.94      0.94       200
#        Piston       0.97      0.95      0.96       200
#     Tensioner       0.98      0.92      0.95       200
#        Slider       0.93      0.89      0.91       200
#        Roller       0.93      0.91      0.92       200
#    Face-Drive       0.94      0.88      0.91       200
#
#      accuracy                           0.92      1600
#     macro avg       0.93      0.92      0.92      1600
#  weighted avg       0.93      0.92      0.92      1600

# %%
cm = confusion_matrix(y_test_svm, test_pred)

plt.figure(figsize=(8,6))

sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap= 'Blues',
    xticklabels=CLASSES,
    yticklabels=CLASSES
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - YAMNet + SVM")

plt.tight_layout()
os.makedirs(_ASSETS_DIR, exist_ok=True)
plt.savefig(os.path.join(_ASSETS_DIR, "confusion_matrix_svm.png"), dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Save Model

# %%
import os

SVM_DIRS = {
    'model': os.path.join(PATHS['models'], 'svm', 'model'),
    'scaler': os.path.join(PATHS['models'], 'svm', 'scaler'),
    'metadata': os.path.join(PATHS['models'], 'svm', 'metadata'),
}

for path in SVM_DIRS.values():
    os.makedirs(path, exist_ok=True)

for key, path in SVM_DIRS.items():
    print(f"{key:<10}: {path}")
# Out:
# model     : models/svm/model
# scaler    : models/svm/scaler
# metadata  : models/svm/metadata

# %%
import joblib

svm_path = os.path.join(
    SVM_DIRS['model'],
    'yamnet_svm.joblib'
)

joblib.dump(
    svm_model,
    svm_path
)

print(f"Saved SVM : {svm_path}")

joblib.dump(
    scaler_svm,
    os.path.join(
        SVM_DIRS['scaler'],
        'yamnet_svm_scaler.joblib'
    )
)

print("SVM scaler saved")

with open(
    os.path.join(
        SVM_DIRS['metadata'],
        'metadata.json'
    ),
    'w'
) as f:
    json.dump(metadata, f, indent=4)
# Out:
# Saved SVM : models/svm/model/yamnet_svm.joblib
# SVM scaler saved

# %% [markdown]
# ## 8.3 Random Forest

# %%
print("\nPersiapan fitur untuk Random Forest...")

X_train_rf = X_train_yn.copy()
X_val_rf   = X_val_yn.copy()
X_test_rf  = X_test_yn.copy()

y_train_rf = y_train_yn
y_val_rf   = y_val_yn
y_test_rf  = y_test_yn
# Out:
# Persiapan fitur untuk Random Forest...

# %%
rf_model = RandomForestClassifier(
    n_estimators=300,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    random_state=42,
    n_jobs=-1
)

print("Training Random Forest...")

rf_model.fit(X_train_rf, y_train_rf)

val_pred_rf = rf_model.predict(X_val_rf)

val_acc_rf = accuracy_score(y_val_rf, val_pred_rf)

print(f"Validation Accuracy RF : {val_acc_rf*100:.2f}%")

test_pred_rf = rf_model.predict(X_test_rf)

test_acc_rf = accuracy_score(y_test_rf, test_pred_rf)

print(f"Test Accuracy RF : {test_acc_rf*100:.2f}%")
# Out:
# Training Random Forest...
# Validation Accuracy RF : 94.18%
# Test Accuracy RF : 92.31%

# %%
print(
    classification_report(
        y_test_rf,
        test_pred_rf,
        target_names=CLASSES
    )
)
# Out:
#                precision    recall  f1-score   support
#
#   Clutch-Shoe       0.91      0.94      0.92       200
# Conecting-Rod       0.96      0.98      0.97       200
#    Drive-Belt       0.92      0.94      0.93       200
#        Piston       0.94      0.96      0.95       200
#     Tensioner       0.94      0.91      0.93       200
#        Slider       0.89      0.89      0.89       200
#        Roller       0.94      0.86      0.90       200
#    Face-Drive       0.89      0.90      0.89       200
#
#      accuracy                           0.92      1600
#     macro avg       0.92      0.92      0.92      1600
#  weighted avg       0.92      0.92      0.92      1600

# %%
cm_rf = confusion_matrix(y_test_rf, test_pred_rf)

plt.figure(figsize=(8,6))

sns.heatmap(
    cm_rf,
    annot=True,
    fmt='d',
    cmap= 'Blues',
    xticklabels=CLASSES,
    yticklabels=CLASSES
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - YAMNet + Random Forest")

plt.tight_layout()
os.makedirs(_ASSETS_DIR, exist_ok=True)
plt.savefig(os.path.join(_ASSETS_DIR, "confusion_matrix_rf.png"), dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Save Model

# %%
import os

RF_DIRS = {
    'model': os.path.join(PATHS['models'], 'random_forest', 'model'),
    'scaler': os.path.join(PATHS['models'], 'random_forest', 'scaler'),
    'metadata': os.path.join(PATHS['models'], 'random_forest', 'metadata'),
}

for path in RF_DIRS.values():
    os.makedirs(path, exist_ok=True)

for key, path in RF_DIRS.items():
    print(f"{key:<10}: {path}")
# Out:
# model     : models/random_forest/model
# scaler    : models/random_forest/scaler
# metadata  : models/random_forest/metadata

# %%
import joblib

rf_path = os.path.join(
    RF_DIRS['model'],
    'yamnet_rf.joblib'
)

joblib.dump(
    rf_model,
    rf_path
)

print(f"Saved RF : {rf_path}")

with open(
    os.path.join(
        RF_DIRS['metadata'],
        'metadata.json'
    ),
    'w'
) as f:
    json.dump(metadata, f, indent=4)
# Out:
# Saved RF : models/random_forest/model/yamnet_rf.joblib

# %% [markdown]
# ## Perbandingan Model

# %%
def evaluate_model(name, y_true, y_pred):

    acc = accuracy_score(y_true, y_pred)

    prec = precision_score(
        y_true,
        y_pred,
        average='weighted',
        zero_division=0
    )

    rec = recall_score(
        y_true,
        y_pred,
        average='weighted'
    )

    f1 = f1_score(
        y_true,
        y_pred,
        average='weighted'
    )

    print(f"\n{name}")
    print(f"Accuracy  : {acc:.4f}")
    print(f"Precision : {prec:.4f}")
    print(f"Recall    : {rec:.4f}")
    print(f"F1 Score  : {f1:.4f}")

evaluate_model(
    "Squential",
    y_test_sq,
    y_pred
)

evaluate_model(
    "SVM",
    y_test_yn,
    test_pred
)

evaluate_model(
    "Random Forest",
    y_test_yn,
    test_pred_rf
)
# Out:
# Squential
# Accuracy  : 0.9575
# Precision : 0.9576
# Recall    : 0.9575
# F1 Score  : 0.9575
#
# SVM
# Accuracy  : 0.9231
# Precision : 0.9289
# Recall    : 0.9231
# F1 Score  : 0.9242
#
# Random Forest
# Accuracy  : 0.9231
# Precision : 0.9233
# Recall    : 0.9231
# F1 Score  : 0.9229

# %% [markdown]
# ## 10. Inference Pipeline
#
# Pengujian model pada data raw `.wav`.

# %%
SEQ_MODEL_PATH = os.path.join(PATHS['models'], 'sequential', 'tflite', 'yamnet_sequential.tflite')

try:
    
    interpreter = tf.lite.Interpreter(model_path=SEQ_MODEL_PATH)
    interpreter.allocate_tensors()
    
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()
    
    print(f"   Model loaded from: {SEQ_MODEL_PATH}")
    print(f"   Model input shape: {input_details[0]['shape']}")
    print(f"   Model output shape: {output_details[0]['shape']}")
except FileNotFoundError:
    print(f"   Model tidak ditemukan di: {SEQ_MODEL_PATH}")
    print(f"   Pastikan model sudah disimpan terlebih dahulu")
except Exception as e:
    print(f"   Error loading model: {e}")

print("\n Loading Scaler...")
SCALER_PATH = os.path.join(PATHS['models'], 'sequential', 'scaler', 'yamnet_scaler.joblib')

try:

    scaler = joblib.load(SCALER_PATH)
    print(f"   Scaler loaded from: {SCALER_PATH}")
except FileNotFoundError:
    print(f"   Scaler tidak ditemukan di: {SCALER_PATH}")
    print(f"   Pastikan scaler sudah disimpan terlebih dahulu")
except Exception as e:
    print(f"   Error loading scaler: {e}")
# Out:
#    Model loaded from: models/sequential/tflite/yamnet_sequential.tflite
#    Model input shape: [   1 1024]
#    Model output shape: [1 8]
#
#  Loading Scaler...
#    Scaler loaded from: models/sequential/scaler/yamnet_scaler.joblib
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
import os
import io
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
import librosa
import joblib
import ipywidgets as widgets
from IPython.display import Audio, display, clear_output

print("Memuat komponen model...")

try:
    yamnet_model = hub.load('https://tfhub.dev/google/yamnet/1')
    print(" YAMNet loaded successfully")
except Exception as e:
    print(f" Error loading YAMNet: {e}")

SEQ_MODEL_PATH = os.path.join(PATHS['models'], 'sequential', 'tflite', 'yamnet_sequential.tflite')
try:
    interpreter = tf.lite.Interpreter(model_path=SEQ_MODEL_PATH)
    interpreter.allocate_tensors()
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()
    print(f" TFLite Model loaded from: {SEQ_MODEL_PATH}")
except Exception as e:
    print(f" Error loading TFLite model: {e}")

SCALER_PATH = os.path.join(PATHS['models'], 'sequential', 'scaler', 'yamnet_scaler.joblib')
try:
    scaler = joblib.load(SCALER_PATH)
    print(f" Scaler loaded from: {SCALER_PATH}")
except Exception as e:
    print(f" Error loading scaler: {e}")

def preprocess_audio_for_inference(audio_bytes):
    """Preprocessing sinkron dengan pipeline training."""

    wav, sr = librosa.load(io.BytesIO(audio_bytes), sr=16000, mono=True)

    wav, _ = librosa.effects.trim(wav, top_db=30)

    wav_norm = wav / (np.max(np.abs(wav)) + 1e-8)

    scores, embeddings, spectrogram = yamnet_model(wav_norm)
    emb = embeddings.numpy()

    emb_mean = np.mean(emb, axis=0)
    
    return emb_mean, wav_norm

def display_prediction_result(filename, model_name, predicted_class, confidence):
    """Fungsi pembantu untuk mencetak hasil dengan rapi."""
    print(f"\n🎯 HASIL PREDIKSI [{model_name}]:")
    print(f"   File       : {filename}")
    print(f"   Kelas      : {predicted_class}")
    print(f"   Confidence : {confidence:.2%}")

def inference_sequential(audio_bytes, filename):
    """Menjalankan inference menggunakan model TFLite."""
    try:

        embedding, wav_norm = preprocess_audio_for_inference(audio_bytes)
        
        embedding_scaled = scaler.transform(embedding.reshape(1, -1))
        
        input_data = np.array(embedding_scaled, dtype=np.float32)
        expected_shape = input_details[0]['shape']
        
        if list(input_data.shape) != list(expected_shape):
            input_data = input_data.reshape(expected_shape)
            
        interpreter.set_tensor(input_details[0]['index'], input_data)
        interpreter.invoke()
        prediction = interpreter.get_tensor(output_details[0]['index'])
        
        predicted_class_idx = np.argmax(prediction, axis=1)[0]
        predicted_class = CLASSES[predicted_class_idx]
        confidence = float(prediction[0][predicted_class_idx])
        
        print("\n🎵 Audio yang diproses:")
        display(Audio(wav_norm, rate=16000))
        
        display_prediction_result(filename, "TFLite", predicted_class, confidence)
        
        print("\n Probabilitas per kelas:")
        for i, cls in enumerate(CLASSES):
            prob = prediction[0][i]
            prob_clamped = max(0.0, min(1.0, prob)) 
            bar = ' ' * int(prob_clamped * 50)
            marker = "->" if i == predicted_class_idx else "  "
            print(f"{marker} {cls:<15}: {prob:.4f} |{bar}")
            
        return predicted_class, confidence, prediction[0]

    except Exception as e:
        print(f"\nTerjadi kesalahan saat memproses '{filename}': {e}")
        return None, None, None

upload_widget = widgets.FileUpload(
    accept='.wav,.mp3,.m4a',
    multiple=False,
    description='1. Upload Audio',
    button_style='info'
)

button_predict = widgets.Button(
    description='2. Klasifikasi',
    button_style='success',
    icon='check'
)

output_area = widgets.Output()

def on_predict_clicked(b):
    with output_area:
        clear_output()
        
        if not upload_widget.value:
            print("Silakan upload file audio terlebih dahulu!")
            return
            
        try:

            if isinstance(upload_widget.value, tuple):

                uploaded_file = upload_widget.value[0]
                filename = uploaded_file['name']
                audio_bytes = uploaded_file['content']
            elif isinstance(upload_widget.value, dict):

                filename = list(upload_widget.value.keys())[0]
                audio_bytes = upload_widget.value[filename]['content']
            else:
                print("Format file upload tidak dikenali oleh widget.")
                return

            print(f"Memproses: {filename}...")
            inference_sequential(audio_bytes, filename)
            
        except Exception as e:
             print(f"Terjadi kesalahan pembacaan file widget: {e}")

button_predict.on_click(on_predict_clicked)


print("Pilih file audio, lalu klik 'Klasifikasi'.")
display(widgets.HBox([upload_widget, button_predict]))
display(output_area)
# Out:
# Memuat komponen model...
#  YAMNet loaded successfully
#  TFLite Model loaded from: models/sequential/tflite/yamnet_sequential.tflite
#  Scaler loaded from: models/sequential/scaler/yamnet_scaler.joblib
# Pilih file audio, lalu klik 'Klasifikasi'.
# HBox(children=(FileUpload(value=(), accept='.wav,.mp3,.m4a', button_style='info', description='1. Upload Audio…
# Output()

# %%
pip freeze >  requirement.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
